# %%
import datetime

# %%
import pandas as pd
import pickle
from collections import Counter
import glob

# %%
dd=pd.read_stata('Sentencing/sentencing_since_1991.dta')

# %%
def combinations(line):
    l = line.strip().split(',')
    combs=[]        
    for i in range(2, len(l)+1):
        els = [",".join(x) for x in itertools.combinations(l, i)]
        combs.extend(els)
    return combs

# %%
newdd=dd[['dateofsentencing','district','lengthofprisonsentence']]

# %%
newdd=newdd[newdd.dateofsentencing.isnull()==False]

# %%
newdd.dateofsentencing[newdd.dateofsentencing.astype(int)>500000]+=19000000

# %%
newdd.dateofsentencing[newdd.dateofsentencing.astype(int)<=500000]+=20000000
# Out:
# C:\Users\zxy\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
newdd['Date']=newdd.dateofsentencing.astype(int).astype(str)

# %%
newdd['date']=pd.to_datetime(newdd['Date'])

# %%
def convertlength(df):
    orig_leng = df["lengthofprisonsentence"]
    if len(orig_leng) < 2:
        return None
    elif orig_leng[-1] == "Y":
        return int(orig_leng[:-1])*12
    elif orig_leng[-1] == "M":
        return int(orig_leng[:-1])
    else:
        return None
newdd["lengthofprisonsentence"] = newdd.apply(convertlength, axis=1)

# %%
newdd=newdd[newdd.lengthofprisonsentence.isnull()==False]
newdd[['district','lengthofprisonsentence','date']]
# Out:
#         district  lengthofprisonsentence       date
# 1           26.0                   300.0 1994-03-21
# 2           26.0                     6.0 1995-12-20
# 3           26.0                    33.0 1995-07-14
# 4           26.0                   108.0 1992-04-20
# 5           26.0                    15.0 1993-10-18
# 6           26.0                    20.0 1994-01-27
# 7           26.0                    10.0 1993-06-28
# 8           26.0                    46.0 1994-04-20
# 9           26.0                     5.0 1995-02-01
# 10          26.0                    21.0 1997-01-17
# 11          26.0                   120.0 1995-03-03
# 12          26.0                    60.0 1995-03-03
# 13          26.0                    30.0 1994-06-29
# 14          26.0                    33.0 1993-10-25
# 15          26.0                    30.0 1995-09-27
# 16          26.0                    46.0 1996-08-27
# 17          26.0                    21.0 1996-11-15
# 18          26.0                    27.0 1996-06-24
# 19          26.0                     6.0 1996-10-03
# 20          26.0                    37.0 1995-11-17
# 21          26.0                    27.0 1993-08-26
# 22          26.0                    12.0 1994-05-17
# 23          26.0                    10.0 1997-07-31
# 24          26.0                    41.0 1995-07-14
# 25          26.0                    13.0 1994-02-11
# 26          26.0                     3.0 1995-09-27
# 27          26.0                    72.0 1993-06-01
# 28          26.0                     5.0 1996-04-03
# 29          26.0                     1.0 1994-09-22
# 30          26.0                    24.0 1994-05-12
# ...          ...                     ...        ...
# 267170       1.0                     4.0 1997-12-18
# 267171       1.0                    14.0 1993-06-15
# 267172       1.0                    12.0 2000-11-28
# 267173       1.0                   102.0 2001-10-25
# 267174       1.0                     6.0 1995-04-18
# 267175       1.0                    46.0 2001-12-14
# 267176       1.0                   180.0 1995-10-10
# 267177       1.0                    15.0 1994-10-12
# 267178       1.0                   180.0 2000-07-19
# 267179       1.0                    41.0 2003-06-24
# 267180       1.0                    60.0 2002-04-16
# 267181       1.0                    84.0 2000-09-07
# 267185        20010907.0       1.0                    12.0  20010907
# 267186        20011019.0       1.0                     6.0  20011019
# 267187        19940419.0       1.0                    48.0  19940419
# 267188        19940927.0       1.0                    14.0  19940927
# 267189        19930120.0       1.0                    46.0  19930120
# 267190        20030522.0       1.0                    18.0  20030522
# 267191        19920428.0       1.0                    12.0  19920428
# 267192        20030919.0       1.0                    12.0  20030919
# 267193        19930831.0       1.0                     4.0  19930831
# 267194        19930129.0       1.0                    15.0  19930129
# 267195        19940614.0       1.0                     0.0  19940614
# 267196        19930129.0       1.0                    15.0  19930129
# 267197        20021011.0       1.0                    51.0  20021011
# 267198        20021011.0       1.0                    51.0  20021011
# 267199        19930831.0       1.0                     4.0  19930831
# 267200        20010315.0       1.0                    15.0  20010315
#
#              date
# 1      1994-03-21
# 2      1995-12-20
# 3      1995-07-14
# 4      1992-04-20
# 5      1993-10-18
# 6      1994-01-27
# 7      1993-06-28
# 8      1994-04-20
# 9      1995-02-01
# 10     1997-01-17
# 11     1995-03-03
# 12     1995-03-03
# 13     1994-06-29
# 14     1993-10-25
# 15     1995-09-27
# 16     1996-08-27
# 17     1996-11-15
# 18     1996-06-24
# 19     1996-10-03
# 20     1995-11-17
# 21     1993-08-26
# 22     1994-05-17
# 23     1997-07-31
# 24     1995-07-14
# 25     1994-02-11
# 26     1995-09-27
# 27     1993-06-01
# 28     1996-04-03
# 29     1994-09-22
# 30     1994-05-12
# ...           ...
# 267170 1997-12-18
# 267171 1993-06-15
# 267172 2000-11-28
# 267173 2001-10-25
# 267174 1995-04-18
# 267175 2001-12-14
# 267176 1995-10-10
# 267177 1994-10-12
# 267178 2000-07-19
# 267179 2003-06-24
# 267180 2002-04-16
# 267181 2000-09-07
# 267183 2001-09-06
# 267184 1994-02-15
# 267185 2001-09-07
# 267186 2001-10-19
# 267187 1994-04-19
# 267188 1994-09-27
# 267189 1993-01-20
# 267190 2003-05-22
# 267191 1992-04-28
# 267192 2003-09-19
# 267193 1993-08-31
# 267194 1993-01-29
# 267195 1994-06-14
# 267196 1993-01-29
# 267197 2002-10-11
# 267198 2002-10-11
# 267199 1993-08-31
# 267200 2001-03-15
#
# [264539 rows x 5 columns]

# %%
k=pd.read_stata('Case/BloombergVOTELEVEL_Touse.dta')
k=k[k.geniss1==1] ##filter on criminal cases
meta=k[['date','JudgesListTouse','geniss1','Author','songername','caseid','Affirmed','AffirmedInPart','Reversed','ReversedInPart','Vacated','VacatedInPart','Circuit','judgelastname','jOrigname','judgeidentificationnumber','yearq']]

# %%
meta.to_pickle('metadata.pkl')
meta=pickle.load(open("metadata.pkl","rb"))

# %%
group=meta.groupby('caseid', as_index=False)['judgeidentificationnumber'].agg({'list':(lambda x: list(x))})

# %%
merge1=pd.merge(meta, group, how='inner', left_on='caseid', right_on='caseid')

# %%
merge1.rename(columns={'judgeidentificationnumber': 'judgeid1'}, inplace=True)

# %%
merge1['judgeid1']=[item[0] for item in merge1.list]
merge1['judgeid2']=[item[1] for item in merge1.list]
merge1['judgeid3']=[item[2] for item in merge1.list]

# %%
merge1=merge1.drop_duplicates('caseid')

# %%
meta=merge1.drop(['JudgesListTouse','geniss1','songername','jOrigname','judgelastname','list','yearq'],axis=1)

# %%
cc=pickle.load( open( "Sentencing/sentence_data.csv", "rb" ) )

# %%
bio=pd.read_csv('Bio/JudgeBio_x_name.csv')

# %%
merge1=pd.merge(cc, meta, how='inner', left_on='caseid', right_on='caseid')

# %%
merge2=pd.merge(merge1, bio, how='inner', left_on='judgeid1', right_on='id')

# %%
merge3=pd.merge(merge2, bio, how='inner', left_on='judgeid2', right_on='id')

# %%
merge4=pd.merge(merge3, bio, how='inner', left_on='judgeid3', right_on='id')

# %%
merge4
# Out:
#        year      caseid     opinion_type     judge_name  decision       date  \
# 0      1913      XFHQ0D     contentMajOp              J  affirmed 1913-01-31
# 1      1909      XFKI92     contentMajOp     BUFFINGTON  reversed 1909-10-06
# 2      1910      XFK953     contentMajOp     BUFFINGTON  reversed 1910-01-11
# 3      1906      XFKVCI     contentConOp       ARCHBALD  affirmed 1906-07-16
# 4      1906      XFKVCI     contentMajOp           GRAY  affirmed 1906-07-16
# 5      1908      XFL1Q9     contentMajOp         DALLAS  reversed 1908-01-27
# 6      1914      XFHCE0     contentMajOp              J  affirmed 1914-01-19
# 7      1915      XFIFHI     contentMajOp        WOOLLEY  affirmed 1915-01-30
# 8      1916      XFLAJ6     contentMajOp        WOOLLEY  affirmed 1916-03-25
# 9      1917      XFLCES     contentMajOp      McPHERSON  affirmed 1917-02-02
# 10     1919      XFHK7E     contentMajOp     BUFFINGTON  reversed 1919-07-07
# 11     1920      XFKLM9     contentMajOp        WOOLLEY  affirmed 1920-07-13
# 12     1930      X9VBHD     contentMajOp       THOMPSON  affirmed 1930-12-22
# 13     1932      X3MC8P     contentMajOp     PER CURIAM  reversed 1932-08-20
# 14     1935      X3JC5F     contentMajOp        WOOLLEY  reversed 1935-03-25
# 15     1922      XFPO4C     contentMajOp        WOOLLEY  reversed 1922-06-29
# 16     1924      XFPEKF     contentMajOp          DAVIS  affirmed 1924-02-09
# 17     1925      X3IJOF     contentMajOp     BUFFINGTON  affirmed 1925-06-12
# 18     1925      X9VBOR     contentMajOp        WOOLLEY  affirmed 1925-02-03
# 19     1925      X9VBTA     contentMajOp     BUFFINGTON  affirmed 1925-02-17
# 20     1926      X3C0E7     contentMajOp          DAVIS  reversed 1926-08-23
# 21     1927      X9UDQD     contentMajOp          DAVIS  affirmed 1927-03-07
# 22     1929      X3GNOB     contentMajOp        WOOLLEY  affirmed 1929-11-19
# 23     1932      X3IEFK     contentMajOp     PER CURIAM  reversed 1932-05-21
# 24     1932      X3S81B     contentMajOp          DAVIS  affirmed 1932-02-29
# 25     1932      X3VTQR     contentMajOp          DAVIS  reversed 1932-09-23
# 26     1934      X4625V     contentMajOp     PER CURIAM  affirmed 1934-08-16
# 27     1915      XFIFL1     contentMajOp              J  affirmed 1915-02-18
# 28     1917      XFL3GP     contentMajOp        WOOLLEY  affirmed 1917-08-27
# 29     1919      XFIJPE     contentMajOp         HAIGHT  affirmed 1919-10-28
# ...     ...         ...              ...            ...       ...        ...
# 42940  2011  X1GRK3E003     contentMajOp      WILKINSON  affirmed 2011-12-09
# 42941  2011  X1FTOQ2003     contentMajOp       HAMILTON  affirmed 2011-07-25
# 42942  2012  X1I0BPO003     contentMajOp           DIAZ  affirmed 2012-07-17
# 42943  2011  X1G0MU6003     contentMajOp        GREGORY  affirmed 2011-08-05
# 42944  2011  X1GKAH0003  contentConDisOp          DAVIS  affirmed 2011-10-24
# 42945  2011  X1GKAH0003     contentMajOp      WILKINSON  affirmed 2011-10-24
# 42946  2010  X1CCN5C003     contentMajOp       NIEMEYER  affirmed 2010-01-12
# 42947  2013  X1JF214003     contentMajOp          DAVIS  affirmed 2013-03-29
# 42948  2013  X1JMP9G003     contentMajOp           AGEE  affirmed 2013-05-29
# 42949  2012  X1H0BUK003     contentMajOp        GREGORY  affirmed 2012-01-17
# 42950  2012  X1IU4F6003     contentMajOp          DAVIS  affirmed 2012-11-29
# 42951  2013  X1L96J8003     contentMajOp          DAVIS  affirmed 2013-11-18
# 42952  1985      X3UUOF     contentMajOp           NIES  affirmed 1985-05-10
# 42953  1986      XAFH0B     contentMajOp           NIES  affirmed 1986-08-08
# 42954  1995      X39T3G     contentMajOp         NEWMAN  reversed 1995-11-29
# 42955  1989      X46CAF     contentMajOp         NEWMAN  affirmed 1989-05-23
# 42956  2002      X275P8     contentMajOp          PROST  affirmed 2002-12-19
# 42957  2013  X1K9Q04003     contentMajOp     PER CURIAM  affirmed 2013-08-27
# 42958  2012  X1HTFHG003     contentMajOp       GERARD E  affirmed 2012-06-27
# 42959  2012  X1I51K4003     contentMajOp         JOHN M  reversed 2012-08-24
# 42960  2005  X13SH9A003     contentMajOp         FISHER  affirmed 2005-12-29
# 42961  2009  X1BH1AO003     contentMajOp     FRANKLIN S  affirmed 2008-06-09
# 42962  2011  X1EU51M003     contentMajOp  VAN ANTWERPEN  affirmed 2011-02-01
# 42963  2012  X1I5OE0003     contentMajOp           AGEE  affirmed 2012-08-30
# 42964  2006  X15LIEC003     contentMajOp          PROST  reversed 2006-09-18
# 42965  1997      X4PPEA     contentMajOp          MAYER  reversed 1997-05-20
# 42966  2009  X1AM268003     contentMajOp         SCHALL  affirmed 2009-03-05
# 42967  1998      XACCED     contentMajOp     PER CURIAM  affirmed 1998-10-14
# 42968  1996      X3A7EO     contentMajOp      CLEVENGER  affirmed 1996-07-15
# 42969  2002      XE4PP7     contentMajOp         SCHALL  affirmed 2002-09-04
#
#               Author  Affirmed  AffirmedInPart  Reversed   ...    x_sdem  \
# 0          MCPHERSON       1.0             0.0       0.0   ...        28
# 1         BUFFINGTON       0.0             0.0       1.0   ...        28
# 2         BUFFINGTON       1.0             0.0       0.0   ...        28
# 3               GRAY       1.0             0.0       0.0   ...        28
# 42966         SCHALL       1.0             0.0       0.0   ...        45
# 42967     PER CURIAM       1.0             0.0       0.0   ...        54
# 42968      CLEVENGER       1.0             0.0       0.0   ...        54
# 42969         SCHALL       1.0             0.0       0.0   ...        53
#
#        x_srep  x_hother  x_sother x_agecommi                        fullname  \
# 0          54       9.0      16.0         59                    GRAY, GEORGE
# 1          54       9.0      16.0         59                    GRAY, GEORGE
# 2          54       9.0      16.0         59                    GRAY, GEORGE
# 3          54       9.0      16.0         59                    GRAY, GEORGE
# 4          54       9.0      16.0         59                    GRAY, GEORGE
# 5          54       9.0      16.0         59                    GRAY, GEORGE
# 6          54       9.0      16.0         59                    GRAY, GEORGE
# 7          44      18.0       1.0         47              WOOLLEY, VICTOR B.
# 8          44      18.0       1.0         47              WOOLLEY, VICTOR B.
# 9          44      18.0       1.0         47              WOOLLEY, VICTOR B.
# 10         44      18.0       1.0         47              WOOLLEY, VICTOR B.
# 11         44      18.0       1.0         47              WOOLLEY, VICTOR B.
# 12         44      18.0       1.0         47              WOOLLEY, VICTOR B.
# 13         44      18.0       1.0         47              WOOLLEY, VICTOR B.
# 14         44      18.0       1.0         47              WOOLLEY, VICTOR B.
# 15         44      18.0       1.0         47              WOOLLEY, VICTOR B.
# 16         44      18.0       1.0         47              WOOLLEY, VICTOR B.
# 17         44      18.0       1.0         47              WOOLLEY, VICTOR B.
# 18         44      18.0       1.0         47              WOOLLEY, VICTOR B.
# 19         44      18.0       1.0         47              WOOLLEY, VICTOR B.
# 20         44      18.0       1.0         47              WOOLLEY, VICTOR B.
# 21         44      18.0       1.0         47              WOOLLEY, VICTOR B.
# 22         44      18.0       1.0         47              WOOLLEY, VICTOR B.
# 23         44      18.0       1.0         47              WOOLLEY, VICTOR B.
# 24         44      18.0       1.0         47              WOOLLEY, VICTOR B.
# 25         44      18.0       1.0         47              WOOLLEY, VICTOR B.
# 26         44      18.0       1.0         47              WOOLLEY, VICTOR B.
# 27         44      18.0       1.0         47              WOOLLEY, VICTOR B.
# 28         44      18.0       1.0         47              WOOLLEY, VICTOR B.
# 29         44      18.0       1.0         47              WOOLLEY, VICTOR B.
# ...       ...       ...       ...        ...                             ...
# 42940      42       0.0       5.0         50                    DIAZ, ALBERT
# 42941      42       0.0       5.0         50                    DIAZ, ALBERT
# 42942      42       0.0       5.0         50                    DIAZ, ALBERT
# 42943      42       0.0       5.0         50                    DIAZ, ALBERT
# 42944      40       0.0       5.0         60                 DAVIS, ANDRE M.
# 42945      40       0.0       5.0         60                 DAVIS, ANDRE M.
# 42946      40       0.0       5.0         60                 DAVIS, ANDRE M.
# 42947      40       0.0       5.0         60                 DAVIS, ANDRE M.
# 42948      40       0.0       5.0         60                 DAVIS, ANDRE M.
# 42949      40       0.0       5.0         60                 DAVIS, ANDRE M.
# 42950      40       0.0       5.0         60                 DAVIS, ANDRE M.
# 42951      40       0.0       5.0         60                 DAVIS, ANDRE M.
# 42952      42       0.0       6.0         57              NIES, HELEN WILSON
# 42953      42       0.0       6.0         57              NIES, HELEN WILSON
# 42954      55       0.0       6.0         57                 NEWMAN, PAULINE
# 42955      55       0.0       6.0         57                 NEWMAN, PAULINE
# 42956      46       2.0       7.0         50                   PROST, SHARON
# 42957      47       0.0       4.0         65           HURWITZ, ANDREW DAVID
# 42958      47       0.0       4.0         57             DRONEY, CHRISTOPHER
# 42959      47       0.0       4.0         57             DRONEY, CHRISTOPHER
# 42960      51       1.0       1.0         63  VAN ANTWERPEN, FRANKLIN STUART
# 42961      51       1.0       1.0         63  VAN ANTWERPEN, FRANKLIN STUART
# 42962      51       1.0       1.0         63  VAN ANTWERPEN, FRANKLIN STUART
# 42963      47       0.0       4.0         47         THACKER, STEPHANIE DAWN
# 42964      42       1.0       8.0         48           SCHALL, ALVIN ANTHONY
# 42965      42       1.0       8.0         48           SCHALL, ALVIN ANTHONY
# 42966      51       1.0       8.0         55                   LINN, RICHARD
# 42967      44       0.0       8.0         41              RADER, RANDALL RAY
# 42968      44       0.0       8.0         58                  PLAGER, S. JAY
# 42969      46       0.0       7.0         46           MAYER, HALDANE ROBERT
#
#             lastname    firstname  middlename  suffix
# 0               GRAY       GEORGE
# 1               GRAY       GEORGE
# 2               GRAY       GEORGE
# 3               GRAY       GEORGE
# 4               GRAY       GEORGE
# 5               GRAY       GEORGE
# 6               GRAY       GEORGE
# 7            WOOLLEY       VICTOR     BAYNARD
# 8            WOOLLEY       VICTOR     BAYNARD
# 9            WOOLLEY       VICTOR     BAYNARD
# 10           WOOLLEY       VICTOR     BAYNARD
# 11           WOOLLEY       VICTOR     BAYNARD
# 12           WOOLLEY       VICTOR     BAYNARD
# 13           WOOLLEY       VICTOR     BAYNARD
# 14           WOOLLEY       VICTOR     BAYNARD
# 15           WOOLLEY       VICTOR     BAYNARD
# 16           WOOLLEY       VICTOR     BAYNARD
# 17           WOOLLEY       VICTOR     BAYNARD
# 18           WOOLLEY       VICTOR     BAYNARD
# 19           WOOLLEY       VICTOR     BAYNARD
# 20           WOOLLEY       VICTOR     BAYNARD
# 21           WOOLLEY       VICTOR     BAYNARD
# 22           WOOLLEY       VICTOR     BAYNARD
# 23           WOOLLEY       VICTOR     BAYNARD
# 24           WOOLLEY       VICTOR     BAYNARD
# 25           WOOLLEY       VICTOR     BAYNARD
# 26           WOOLLEY       VICTOR     BAYNARD
# 27           WOOLLEY       VICTOR     BAYNARD
# 28           WOOLLEY       VICTOR     BAYNARD
# 29           WOOLLEY       VICTOR     BAYNARD
# ...              ...          ...         ...     ...
# 42940           DIAZ       ALBERT
# 42941           DIAZ       ALBERT
# 42942           DIAZ       ALBERT
# 42943           DIAZ       ALBERT
# 42944          DAVIS        ANDRE     MAURICE
# 42945          DAVIS        ANDRE     MAURICE
# 42946          DAVIS        ANDRE     MAURICE
# 42947          DAVIS        ANDRE     MAURICE
# 42948          DAVIS        ANDRE     MAURICE
# 42949          DAVIS        ANDRE     MAURICE
# 42950          DAVIS        ANDRE     MAURICE
# 42951          DAVIS        ANDRE     MAURICE
# 42952           NIES        HELEN      WILSON
# 42953           NIES        HELEN      WILSON
# 42954         NEWMAN      PAULINE
# 42955         NEWMAN      PAULINE
# 42956          PROST       SHARON
# 42957        HURWITZ       ANDREW       DAVID
# 42958         DRONEY  CHRISTOPHER  FITZGERALD
# 42959         DRONEY  CHRISTOPHER  FITZGERALD
# 42960  VAN ANTWERPEN     FRANKLIN      STUART
# 42961  VAN ANTWERPEN     FRANKLIN      STUART
# 42962  VAN ANTWERPEN     FRANKLIN      STUART
# 42963        THACKER    STEPHANIE        DAWN
# 42964         SCHALL        ALVIN     ANTHONY
# 42965         SCHALL        ALVIN     ANTHONY
# 42966           LINN      RICHARD
# 42967          RADER      RANDALL         RAY
# 42968         PLAGER    S[HELDON]         JAY
# 42969          MAYER      HALDANE      ROBERT
#
# [42970 rows x 287 columns]

# %%
count=k.groupby(['year'])['x_dem'].count()
sum=k.groupby(['year'])['x_dem'].sum()

def dem(year):
    return dict(sum/count)[float(year)]

merge4['x_dem_p']=merge4.year.apply(dem)

# %%
cc=merge4
dc=newdd
cc['month_3']=cc.date+pd.DateOffset(months=3)
cc['month_3_b']=cc.date+pd.DateOffset(months=-3)

def find_date(df):
    min_date = df["month_3_b"]
    date=df["date"]
    max_date = df["month_3"]
    a=dc[(dc['date'] >= date) & (dc['date'] <= max_date)].lengthofprisonsentence.mean()
    b=dc[(dc['date'] >= min_date) & (dc['date'] <= date)].lengthofprisonsentence.mean()

    return a-b

cc["length_3m_dif"] = cc.apply(find_date, axis=1)

# %%
s=cc.dropna(subset = ['length_3m_dif'])

# %%
import nltk
from nltk.util import ngrams
from io import open
import unicodedata
import string
import re

# %%
s['txt']=None
# Out:
# C:\Users\zxy\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
for i,(year,ids,j) in enumerate(zip(s.year,s.caseid,s.judge_name)):
    filepath = "Sentencing/sentences_new/sent_"+str(year)+"/"+ids+"_*_"+j+"*.txt"
    txt = glob.glob(filepath)
    with open (txt[0],encoding="utf8") as f:
        #c=Counter(list(f.read()))
        text=f.read().lower()
        text = re.sub("\n", ' ', text)
        s.txt[i]=text
# Out:
# C:\Users\zxy\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\zxy\Anaconda3\lib\site-packages\pandas\core\series.py:747: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.loc[key] = value
# C:\Users\zxy\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2862: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-873c71f74368> in <module>()
#       1 for i,(year,ids,j) in enumerate(zip(s.year,s.caseid,s.judge_name)):
#       2     filepath = "Sentencing/sentences_new/sent_"+str(year)+"/"+ids+"_*_"+j+"*.txt"
# ----> 3     txt = glob.glob(filepath)
#       4     with open (txt[0],encoding="utf8") as f:
#       5         #c=Counter(list(f.read()))
#
# ~\Anaconda3\lib\glob.py in glob(pathname, recursive)
#      18     zero or more directories and subdirectories.
#      19     """
# ---> 20     return list(iglob(pathname, recursive=recursive))
#      21
#      22 def iglob(pathname, *, recursive=False):
#
# ~\Anaconda3\lib\glob.py in _iglob(pathname, recursive, dironly)
#      70         glob_in_dir = _glob0
#      71     for dirname in dirs:
# ---> 72         for name in glob_in_dir(dirname, basename, dironly):
#      73             yield os.path.join(dirname, name)
#      74
#
# ~\Anaconda3\lib\glob.py in _glob1(dirname, pattern, dironly)
#      78
#      79 def _glob1(dirname, pattern, dironly):
# ---> 80     names = list(_iterdir(dirname, dironly))
#      81     if not _ishidden(pattern):
#      82         names = (x for x in names if not _ishidden(x))
#
# ~\Anaconda3\lib\glob.py in _iterdir(dirname, dironly)
#     121         with os.scandir(dirname) as it:
#     122             for entry in it:
# --> 123                 try:
#     124                     if not dironly or entry.is_dir():
#     125                         yield entry.name
#
# KeyboardInterrupt:

# %%
s.to_pickle('training_data.pkl')

# %%
count=k.groupby(['year'])['x_dem'].count()
sum=k.groupby(['year'])['x_dem'].sum()

def dem(year):
    return dict(sum/count)[float(year)]

merge4['x_dem_p']=merge4.year.apply(dem)
# Out:
#        year        caseid   opinion_type   judge_name  decision       date  \
# 2304   1993        X35807   contentMajOp   PER CURIAM  affirmed 1993-08-04
# 2796   1992        X3AD9D   contentMajOp        LOGAN  affirmed 1992-11-13
# 2805   1992        X3ADTB   contentMajOp        LOGAN  reversed 1992-12-29
# 2814   1997        X37GPR   contentMajOp       JOHN C  affirmed 1997-02-11
# 2816   1999        X4QAM7   contentMajOp     HOLLOWAY  affirmed 1999-01-04
# 2817   1998  XN5ACRQNB5G0   contentMajOp       JOHN C  affirmed 1998-02-23
# 2819   1991        X57EQB   contentMajOp       JOHN P  reversed 1991-12-17
# 2820   1991        XAC38F   contentMajOp       BRORBY  affirmed 1991-12-31
# 2821   1995        X4NT3Q   contentMajOp     HOLLOWAY  affirmed 1995-10-18
# 2822   2000        X3FBF1   contentMajOp        TACHA  affirmed 2000-04-04
# 2823   1998        X369TF   contentMajOp         EBEL  reversed 1998-09-18
# 2824   2001        X50L71   contentMajOp   PAUL KELLY  reversed 2001-03-22
# 2829   1992        X321KN   contentMajOp        LOGAN  affirmed 1992-02-18
# 2830   1996        X36F13   contentMajOp       JOHN C  affirmed 1996-12-31
# 2835   2001        X519BI   contentMajOp     HOLLOWAY  affirmed 2001-10-09
# 2836   2000        X3J03E   contentMajOp     HOLLOWAY  affirmed 2000-12-15
# 2842   1999        X3F6GM   contentMajOp       MURPHY  reversed 1999-12-29
# 3065   1993        X30IAK   contentMajOp       MORGAN  affirmed 1993-05-26
# 3392   1998        X40T80   contentMajOp     HATCHETT  affirmed 1998-12-31
# 3400   1994        X38NGO   contentMajOp         DYER  affirmed 1994-06-22
# 3471   1996        X353L8   contentMajOp      LEVIN H  affirmed 1996-10-10
# 3472   1996  XCBU47QNB5G0   contentMajOp   PER CURIAM  affirmed 1996-06-20
# 3473   1993        X547LG   contentMajOp        RONEY  affirmed 1993-04-23
# 3498   1998        X4VHCE   contentMajOp     HATCHETT  affirmed 1998-07-14
# 3500   1998        X4Q5RR   contentMajOp        RONEY  affirmed 1998-04-10
# 3504   1992        X3VL99   contentMajOp        BIRCH  affirmed 1992-01-10
# 3515   1999        XAFMCU   contentMajOp   PER CURIAM  affirmed 1999-02-08
# 3533   1992        X545RG   contentMajOp    EDMONDSON  affirmed 1992-08-10
# 3535   2002        X4IRLK   contentMajOp     ANDERSON  affirmed 2002-01-15
# 3539   1997        X350CE   contentMajOp      LEVIN H  reversed 1997-01-06
# ...     ...           ...            ...          ...       ...        ...
# 42747  2001        X511N4   contentMajOp     WILLIAMS  reversed 2001-07-12
# 42759  1992        X3P2NH   contentMajOp        ERVIN  affirmed 1992-05-22
# 42773  2003        X9U6JK   contentMajOp      WIDENER  affirmed 2003-05-27
# 42817  1997        X4V0ON   contentMajOp      DAVID A  affirmed 1997-04-14
# 42818  1996        X4ONP1   contentMajOp  NATHANIEL R  reversed 1996-11-08
# 42819  1998        X37OV0   contentMajOp         COLE  reversed 1998-07-15
# 42823  2000        X3FD4R   contentMajOp        MOORE  affirmed 2000-04-11
# 42824  1998  XN5AK7QNB5G0  contentConOp1     WELLFORD  reversed 1998-02-12
# 42825  1998  XN5AK7QNB5G0   contentMajOp      MERRITT  reversed 1998-02-12
# 42826  1997        X3L8SP   contentMajOp        MOORE  affirmed 1997-08-06
# 42827  1996        X3PL8L   contentMajOp        MOORE  affirmed 1996-06-06
# 42828  1998        X3BSB1   contentMajOp        MOORE  affirmed 1998-05-11
# 42829  1998        X3BS2P   contentMajOp        BOGGS  affirmed 1998-05-20
# 42833  2002        X4IRGD   contentMajOp        MOORE  affirmed 2002-01-30
# 42836  1996  XCBUCRQNB5G0   contentMajOp        MOORE  affirmed 1996-06-14
# 42837  2000        X3F9CR   contentMajOp     O MALLEY  affirmed 2000-02-17
# 42850  1997        X37GT2   contentMajOp     O MALLEY  affirmed 1997-02-10
# 42872  1998        X4VH7N  contentDisOp1      WALLACH  reversed 1998-07-21
# 42873  1998        X4VH7N   contentMajOp       NOONAN  affirmed 1998-07-21
# 42897  1997        X3BFO8   contentMajOp   PER CURIAM  affirmed 1997-08-25
# 42899  1996        X53M2P   contentMajOp     FRIEDMAN  affirmed 1996-05-15
# 42900  1993        X330BV   contentMajOp    CLEVENGER  affirmed 1993-06-29
# 42936  2002        X6B9O0   contentMajOp     SLOVITER  reversed 2002-07-03
# 42937  2001        X50SRI   contentMajOp          DYK  affirmed 2001-06-12
# 42954  1995        X39T3G   contentMajOp       NEWMAN  reversed 1995-11-29
# 42956  2002        X275P8   contentMajOp        PROST  affirmed 2002-12-19
# 42965  1997        X4PPEA   contentMajOp        MAYER  reversed 1997-05-20
# 42967  1998        XACCED   contentMajOp   PER CURIAM  affirmed 1998-10-14
# 42968  1996        X3A7EO   contentMajOp    CLEVENGER  affirmed 1996-07-15
# 42969  2002        XE4PP7   contentMajOp       SCHALL  affirmed 2002-09-04
#
#            Author  Affirmed  AffirmedInPart  Reversed  ...   x_agecommi  \
# 2304                    1.0             0.0       0.0  ...           57
# 2796        LOGAN       1.0             0.0       0.0  ...           45
# 2805        LOGAN       0.0             0.0       1.0  ...           45
# 2814     PORFILIO       1.0             0.0       0.0  ...           45
# 2816     HOLLOWAY       1.0             0.0       0.0  ...           45
# 2817     PORFILIO       1.0             0.0       0.0  ...           45
# 2819        MOORE       0.0             0.0       0.0  ...           45
# 2820       BRORBY       1.0             0.0       0.0  ...           45
# 2821     HOLLOWAY       1.0             0.0       0.0  ...           45
# 2822        TACHA       1.0             0.0       0.0  ...           45
# 2823         EBEL       0.0             0.0       1.0  ...           45
# 2824        KELLY       0.0             0.0       1.0  ...           45
# 2829        LOGAN       1.0             0.0       0.0  ...           45
# 2830     PORFILIO       1.0             0.0       0.0  ...           45
# 2835     HOLLOWAY       1.0             0.0       0.0  ...           45
# 2836     HOLLOWAY       1.0             0.0       0.0  ...           45
# 2842                    1.0             0.0       0.0  ...           45
# 3065       MORGAN       1.0             0.0       0.0  ...           55
# 3392     HATCHETT       1.0             0.0       0.0  ...           49
# 3400         DYER       0.0             1.0       0.0  ...           49
# 3471     CAMPBELL       1.0             0.0       0.0  ...           49
# 3472                    1.0             0.0       0.0  ...           49
# 3473        RONEY       1.0             0.0       0.0  ...           49
# 3498     HATCHETT       1.0             0.0       0.0  ...           49
# 3500        RONEY       1.0             0.0       0.0  ...           49
# 3504        BIRCH       0.0             1.0       0.0  ...           49
# 3515                    1.0             0.0       0.0  ...           49
# 3533    EDMONDSON       1.0             0.0       0.0  ...           49
# 3535     ANDERSON       1.0             0.0       0.0  ...           49
# 3539     CAMPBELL       1.0             0.0       0.0  ...           49
# ...           ...       ...             ...       ...  ...          ...
# 42747    WILLIAMS       0.0             0.0       0.0  ...           50
# 42759       ERVIN       1.0             0.0       0.0  ...           49
# 42773                   1.0             0.0       0.0  ...           49
# 42817      NELSON       1.0             0.0       0.0  ...           47
# 42818       JONES       0.0             0.0       1.0  ...           47
# 42819        COLE       1.0             0.0       0.0  ...           47
# 42823       MOORE       1.0             0.0       0.0  ...           47
# 42824     MERRITT       0.0             0.0       1.0  ...           47
# 42825     MERRITT       0.0             0.0       1.0  ...           47
# 42826       MOORE       1.0             0.0       0.0  ...           47
# 42827       MOORE       1.0             0.0       0.0  ...           47
# 42828       MOORE       1.0             0.0       0.0  ...           47
# 42829       BOGGS       1.0             0.0       0.0  ...           47
# 42833       MOORE       0.0             1.0       0.0  ...           47
# 42836       MOORE       1.0             0.0       0.0  ...           47
# 42837    O'MALLEY       1.0             0.0       0.0  ...           47
# 42850    O'MALLEY       1.0             0.0       0.0  ...           54
# 42872      NOONAN       1.0             0.0       0.0  ...           62
# 42873      NOONAN       1.0             0.0       0.0  ...           62
# 42897  PER CURIAM       1.0             0.0       0.0  ...           56
# 42899    FRIEDMAN       1.0             0.0       0.0  ...           53
# 42900   CLEVENGER       1.0             0.0       0.0  ...           53
# 42936                   0.0             0.0       0.0  ...           47
# 42937         DYK       1.0             0.0       0.0  ...           47
# 42954      NEWMAN       0.0             0.0       1.0  ...           57
# 42956       PROST       1.0             0.0       0.0  ...           50
# 42965       MAYER       0.0             0.0       1.0  ...           48
# 42967  PER CURIAM       1.0             0.0       0.0  ...           41
# 42968   CLEVENGER       1.0             0.0       0.0  ...           58
# 42969      SCHALL       1.0             0.0       0.0  ...           46
#
#                               fullname   lastname  firstname middlename  \
# 2304               TUTTLE, ELBERT PARR     TUTTLE     ELBERT       PARR
# 2796                 HOLLOWAY, WILLIAM   HOLLOWAY    WILLIAM     JUDSON
# 2805                 HOLLOWAY, WILLIAM   HOLLOWAY    WILLIAM     JUDSON
# 2814                 HOLLOWAY, WILLIAM   HOLLOWAY    WILLIAM     JUDSON
# 2816                 HOLLOWAY, WILLIAM   HOLLOWAY    WILLIAM     JUDSON
# 2817                 HOLLOWAY, WILLIAM   HOLLOWAY    WILLIAM     JUDSON
# 2819                 HOLLOWAY, WILLIAM   HOLLOWAY    WILLIAM     JUDSON
# 2820                 HOLLOWAY, WILLIAM   HOLLOWAY    WILLIAM     JUDSON
# 2821                 HOLLOWAY, WILLIAM   HOLLOWAY    WILLIAM     JUDSON
# 2822                 HOLLOWAY, WILLIAM   HOLLOWAY    WILLIAM     JUDSON
# 2823                 HOLLOWAY, WILLIAM   HOLLOWAY    WILLIAM     JUDSON
# 2824                 HOLLOWAY, WILLIAM   HOLLOWAY    WILLIAM     JUDSON
# 2829                 HOLLOWAY, WILLIAM   HOLLOWAY    WILLIAM     JUDSON
# 2830                 HOLLOWAY, WILLIAM   HOLLOWAY    WILLIAM     JUDSON
# 2835                 HOLLOWAY, WILLIAM   HOLLOWAY    WILLIAM     JUDSON
# 2836                 HOLLOWAY, WILLIAM   HOLLOWAY    WILLIAM     JUDSON
# 2842                 HOLLOWAY, WILLIAM   HOLLOWAY    WILLIAM     JUDSON
# 3065              MORGAN, LEWIS RENDER     MORGAN      LEWIS     RENDER
# 3392                    RONEY, PAUL H.      RONEY       PAUL      HITCH
# 3400                    RONEY, PAUL H.      RONEY       PAUL      HITCH
# 3471                    RONEY, PAUL H.      RONEY       PAUL      HITCH
# 3472                    RONEY, PAUL H.      RONEY       PAUL      HITCH
# 3473                    RONEY, PAUL H.      RONEY       PAUL      HITCH
# 3498                    RONEY, PAUL H.      RONEY       PAUL      HITCH
# 3500                    RONEY, PAUL H.      RONEY       PAUL      HITCH
# 3504                    RONEY, PAUL H.      RONEY       PAUL      HITCH
# 3515                    RONEY, PAUL H.      RONEY       PAUL      HITCH
# 3533                    RONEY, PAUL H.      RONEY       PAUL      HITCH
# 3535                    RONEY, PAUL H.      RONEY       PAUL      HITCH
# 3539                    RONEY, PAUL H.      RONEY       PAUL      HITCH
# ...                                ...        ...        ...        ...
# 42747             WILLIAMS, ANN CLAIRE   WILLIAMS        ANN     CLAIRE
# 42759                 SHEDD, DENNIS W.      SHEDD     DENNIS         W.
# 42773                 SHEDD, DENNIS W.      SHEDD     DENNIS         W.
# 42817              MOORE, KAREN NELSON      MOORE      KAREN     NELSON
# 42818              MOORE, KAREN NELSON      MOORE      KAREN     NELSON
# 42819              MOORE, KAREN NELSON      MOORE      KAREN     NELSON
# 42823              MOORE, KAREN NELSON      MOORE      KAREN     NELSON
# 42824              MOORE, KAREN NELSON      MOORE      KAREN     NELSON
# 42825              MOORE, KAREN NELSON      MOORE      KAREN     NELSON
# 42826              MOORE, KAREN NELSON      MOORE      KAREN     NELSON
# 42827              MOORE, KAREN NELSON      MOORE      KAREN     NELSON
# 42828              MOORE, KAREN NELSON      MOORE      KAREN     NELSON
# 42829              MOORE, KAREN NELSON      MOORE      KAREN     NELSON
# 42833              MOORE, KAREN NELSON      MOORE      KAREN     NELSON
# 42836              MOORE, KAREN NELSON      MOORE      KAREN     NELSON
# 
# 42773        2003-02-27 2003-08-27      -0.182403  None
# 42817        1997-01-14 1997-07-14       1.369682  None
# 42818        1996-08-08 1997-02-08      -0.721448  None
# 42819        1998-04-15 1998-10-15      -1.672693  None
# 42823        2000-01-11 2000-07-11      -0.582892  None
# 42824        1997-11-12 1998-05-12       4.391114  None
# 42825        1997-11-12 1998-05-12       4.391114  None
# 42826        1997-05-06 1997-11-06       3.077734  None
# 42827        1996-03-06 1996-09-06      -1.534347  None
# 42828        1998-02-11 1998-08-11      -3.289054  None
# 42829        1998-02-20 1998-08-20      -2.744345  None
# 42833        2001-10-30 2002-04-30       1.911132  None
# 42836        1996-03-14 1996-09-14      -3.518299  None
# 42837        1999-11-17 2000-05-17      -0.010986  None
# 42850        1996-11-10 1997-05-10       0.391228  None
# 42872        1998-04-21 1998-10-21      -1.103230  None
# 42873        1998-04-21 1998-10-21      -1.103230  None
# 42897    JR. 1997-05-25 1997-11-25       4.717174  None
# 42899    III 1996-02-15 1996-08-15      -2.290177  None
# 42900    III 1993-03-29 1993-09-29      -2.343028  None
# 42936        2002-04-03 2002-10-03      -0.452432  None
# 42937        2001-03-12 2001-09-12       0.444905  None
# 42954        1995-08-29 1996-02-29       0.952293  None
# 42956        2002-09-19 2003-03-19       0.600876  None
# 42965        1997-02-20 1997-08-20       1.289229  None
# 42967        1998-07-14 1999-01-14      -0.713856  None
# 42968        1996-04-15 1996-10-15      -1.403785  None
# 42969        2002-06-04 2002-12-04      -0.328113  None
#
# [8434 rows x 291 columns]

# %%
cc=s

# %%
cc=cc.drop(['x_dccircuit_x',
 'x_8circuit_x',
 'x_11circuit_x',
 'x_fcircuit_x',
 'x_5circuit_x',
 'x_1circuit_x',
 'x_4circuit_x',
 'x_9circuit_x',
 'x_2circuit_x',
 'x_7circuit_x',
 'x_6circuit_x',
 'x_10circuit_x',
 'x_3circuit_x','x_dccircuit_y',
 'x_8circuit_y',
 'x_11circuit_y',
 'x_fcircuit_y',
 'x_5circuit_y',
 'x_1circuit_y',
 'x_4circuit_y',
 'x_9circuit_y',
 'x_2circuit_y',
 'x_7circuit_y',
 'x_6circuit_y',
 'x_10circuit_y',
 'x_3circuit_y','x_dccircuit',
 'x_8circuit',
 'x_11circuit',
 'x_fcircuit',
 'x_5circuit',
 'x_1circuit',
 'x_4circuit',
 'x_9circuit',
 'x_2circuit',
 'x_7circuit',
 'x_6circuit',
 'x_10circuit',
 'x_3circuit'],axis=1)

# %%
cols=[col for col in cc if col.startswith('x_')]

# %%
for i in cols:
    dictionary=cc.groupby(['year','x_circuit_x'])[i].mean().to_dict()
    def demean(df):
        circuit = df['x_circuit_x']
        year=df['year']
        before=df[i]
        mean=dictionary[(year,circuit)]
        return before-mean

    cc[i+'_dm'] = cc.apply(demean, axis=1)

# %%
cc=cc.drop(cols+['x_circuit_x','x_circuit_y','x_circuit'],axis=1)

# %%
cc.reset_index().to_pickle('cc_merged_0516.pkl')
